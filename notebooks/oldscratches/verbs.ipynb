# %%
import os 
import numpy as np

import keras

from keras import layers

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

from keras.optimizers import Adam
from keras.utils import to_categorical

# %%
infinitive = []
simple_past = []
past_participle = []

with open('irr_verb_list.txt','r') as f:
    for line in f:
        ln = line.split() 
        infinitive.append(ln[0])
        simple_past.append(ln[1])
        past_participle.append(ln[2])
        
tokenizer = Tokenizer(char_level=True)
tokenizer.fit_on_texts(texts = infinitive + simple_past +past_participle)

training = np.asarray(tokenizer.texts_to_sequences(infinitive))

y1 = pad_sequences(np.array(tokenizer.texts_to_sequences(simple_past)), padding='post')
y2 = pad_sequences(np.array(tokenizer.texts_to_sequences(past_participle)), padding='post')

padded_training = pad_sequences(training, padding='post')
padded_y1 = to_categorical(y1)
padded_y2 = to_categorical(y2)

num_token = np.max(padded_training+1)

# %%
input_dim = padded_training.shape[1]
output_dim = num_token
input_length = padded_training.shape[1]

embedding_out_dim = 4

rnn_units = 48

# %%
encoder_input = keras.Inp
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding (Embedding)        (None, 10, 4)             96
# _________________________________________________________________
# simple_rnn (SimpleRNN)       (None, 10, 48)            2544
# _________________________________________________________________
# dense (Dense)                (None, 10, 24)            1176
# ...
# Total params: 3,816
# Trainable params: 3,816
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = Adam(learning_rate=0.01)

# %%
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(padded_training, padded_y1, batch_size=128, epochs=2000, shuffle=True, verbose=3)
# Out:
# 734/2000
# Epoch 735/2000
# Epoch 736/2000
# Epoch 737/2000
# Epoch 738/2000
# Epoch 739/2000
# Epoch 740/2000
# Epoch 741/2000
# Epoch 742/2000
# Epoch 743/2000
# Epoch 744/2000
# Epoch 745/2000
# Epoch 746/2000
# Epoch 747/2000
# Epoch 748/2000
# Epoch 749/2000
# Epoch 750/2000
# Epoch 751/2000
# Epoch 752/2000
# Epoch 753/2000
# Epoch 754/2000
# Epoch 755/2000
# Epoch 756/2000
# Epoch 757/2000
# Epoch 758/2000
# Epoch 759/2000
# Epoch 760/2000
# Epoch 761/2000
# Epoch 762/2000
# Epoch 763/2000
# Epoch 764/2000
# Epoch 765/2000
# Epoch 766/2000
# Epoch 767/2000
# Epoch 768/2000
# Epoch 769/2000
# Epoch 770/2000
# Epoch 771/2000
# Epoch 772/2000
# Epoch 773/2000
# Epoch 774/2000
# Epoch 775/2000
# Epoch 776/2000
# Epoch 777/2000
# Epoch 778/2000
# Epoch 779/2000
# Epoch 780/2000
# Epoch 781/2000
# Epoch 782/2000
# Epoch 783/2000
# Epoch 784/2000
# Epoch 785/2000
# Epoch 786/2000
# Epoch 787/2000
# Epoch 788/2000
# Epoch 789/2000
# Epoch 790/2000
# Epoch 791/2000
# Epoch 792/2000
# ...

# %%
predict =model.predict(padded_training)

# %%
predict_idx = np.argmax(predict, axis=2)
# Out:
# 0

# %%
tokenizer.sequences_to_texts(predict_idx)
# Out:
# ['a b o d e e e e e e',
#  'a r o s e e e e e e',
#  'a w o k e e e e e e',
#  'b e e e e e e e e e',
#  'b e a e e e e e e e',
#  'b e a t t t t t t t',
#  'b e c a m e e e e e',
#  'b e f e l l l l l l',
#  'b e g o t t t t t t',
#  'b e g a n n n n n n',
#  'b e h e l d d d d d',
#  'b e n t t t t t t t',
#  'b e r e f t',
#  'b e s e u g h h h h',
#  'b e s e t t t t t t',
#  'b e s p o k e e e e',
#  'b e s t r o d e e e',
#  'b e t t t t t t t t',
#  'b i d d d d d d d d',
#  'b i u n n n n n n n',
#  'b i t',
#  'b l e d',
#  'b l e w w w w w w w',
#  'b r o k e e e e e e',
#  'b r o d',
#  'b r o u g g g g g g',
#  'b r o a d c a s t t',
#  'b u i l t t t t t t',
#  'b u r n n n n n n n',
#  'b u r s t t t t t t',
#  'b u u u u u u u u u',
#  'c a u u u u u u u u',
#  'c a s t t t t t t t',
#  'c a u g h h h h h h',
#  'c h o s e',
#  'c l u n g g g g g g',
#  'c o m e e e e e e e',
#  'c o s t t t t t t t',
#  'c r e p t t t t t t',
#  'c u t t t t t t t t',
# ...
